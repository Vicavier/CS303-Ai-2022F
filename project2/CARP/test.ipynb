# %%
import numpy as np

a = [4] *2 * 8
a
# Out:
# [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# pathScanning:      4201, 6446, 370, 309, 212, 504, 370
# pathScanning-Pro:  3774, 5608, 316, 275, 173, 410, 290
# argument-merge:    5060, 7076, 395, 339, 197, 492, 352
# MEANS:             3589, 5272, 316, 275, 173, 418, 292
data = [['Methond','egl-e1-A','egl-s1-A','gdb1','gdb10','val1A','val4A','val7A'],
        ['path-scanning',4201, 6446, 370, 309, 212, 504, 370],
        ['improved path-scanning',3774, 5608, 316, 275, 173, 410, 290],
        ['argument-merge',5060, 7076, 395, 339, 197, 492, 352],
        ['MEANS',3589, 5272, 316, 275, 173, 418, 292]]
df = pd.DataFrame(data[1:],columns=data[0])
ps = [4201, 6446, 370, 309, 212, 504, 370]
psi = [3774, 5608, 316, 275, 173, 410, 290]
am = [5060, 7076, 395, 339, 197, 492, 352]
means = [3589, 5272, 316, 275, 173, 418, 292]

plt.hist([ps,psi,am,means],stacked=True)
# Out:
# (array([[ 5.,  0.,  0.,  0.,  0.,  1.,  0.,  0.,  0.,  1.],
#         [10.,  0.,  0.,  0.,  0.,  2.,  0.,  1.,  0.,  1.],
#         [15.,  0.,  0.,  0.,  0.,  2.,  0.,  2.,  0.,  2.],
#         [20.,  0.,  0.,  0.,  1.,  2.,  0.,  3.,  0.,  2.]]),
#  array([ 173. ,  863.3, 1553.6, 2243.9, 2934.2, 3624.5, 4314.8, 5005.1,
#         5695.4, 6385.7, 7076. ]),
#  <a list of 4 BarContainer objects>)
